# %%
# %tensorflow_version 1.x

from google.colab import drive
drive.mount('/content/drive/', force_remount=True)
# Out:
# TensorFlow 1.x selected.
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive/

# %%
random_state = 523 # Fixed seed for replicability of randomic operations.
resultsDir = "./data/results"

# %%
# !pip install pandas keras
# Out:
# Requirement already satisfied: pandas in d:\tweepfake_deepfake_text_detection\venv\lib\site-packages (0.25.3)
# Requirement already satisfied: keras in d:\tweepfake_deepfake_text_detection\venv\lib\site-packages (2.10.0)
# Requirement already satisfied: pytz>=2017.2 in d:\tweepfake_deepfake_text_detection\venv\lib\site-packages (from pandas) (2018.9)
# Requirement already satisfied: numpy>=1.13.3 in d:\tweepfake_deepfake_text_detection\venv\lib\site-packages (from pandas) (1.18.5)
# Requirement already satisfied: python-dateutil>=2.6.1 in d:\tweepfake_deepfake_text_detection\venv\lib\site-packages (from pandas) (2.8.1)
# Requirement already satisfied: six>=1.5 in d:\tweepfake_deepfake_text_detection\venv\lib\site-packages (from python-dateutil>=2.6.1->pandas) (1.12.0)
# Collecting sklearn
#   Downloading sklearn-0.0.post12.tar.gz (2.6 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'error'
#   Downloading sklearn-0.0.post11.tar.gz (3.6 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'error'
#   ERROR: Command errored out with exit status 1:
#    command: 'd:\tweepfake_deepfake_text_detection\venv\scripts\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\ESDRAS~1\\AppData\\Local\\Temp\\pip-install-l0xnbmve\\sklearn_521f2ab1e07e4d98932fccf3172b4ea9\\setup.py'"'"'; __file__='"'"'C:\\Users\\ESDRAS~1\\AppData\\Local\\Temp\\pip-install-l0xnbmve\\sklearn_521f2ab1e07e4d98932fccf3172b4ea9\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\ESDRAS~1\AppData\Local\Temp\pip-pip-egg-info-z5adf3nu'
#        cwd: C:\Users\ESDRAS~1\AppData\Local\Temp\pip-install-l0xnbmve\sklearn_521f2ab1e07e4d98932fccf3172b4ea9\
#   Complete output (15 lines):
#   The 'sklearn' PyPI package is deprecated, use 'scikit-learn'
#   rather than 'sklearn' for pip commands.
#
#   Here is how to fix this error in the main use cases:
#   - use 'pip install scikit-learn' rather than 'pip install sklearn'
#   - replace 'sklearn' by 'scikit-learn' in your pip requirements files
#     (requirements.txt, setup.py, setup.cfg, Pipfile, etc ...)
#   - if the 'sklearn' package is used by one of your dependencies,
#   Downloading sklearn-0.0.post10.tar.gz (3.6 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'error'
#   Downloading sklearn-0.0.post9.tar.gz (3.6 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'error'
#   Downloading sklearn-0.0.post7.tar.gz (3.6 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'error'
#   Downloading sklearn-0.0.post5.tar.gz (3.7 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'error'
#     it would be great if you take some time to track which package uses
#     'sklearn' instead of 'scikit-learn' and report it to their issue tracker
#   - as a last resort, set the environment variable
#     SKLEARN_ALLOW_DEPRECATED_SKLEARN_PACKAGE_INSTALL=True to avoid this error
#
#   More information is available at
#   https://github.com/scikit-learn/sklearn-pypi-package
#   ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/46/1c/395a83ee7b2d2ad7a05b453872053d41449564477c81dc356f720b16eac4/sklearn-0.0.post12.tar.gz#sha256=54cff9e20839b7b202321178228af4d9388bedf78425d9299fd9ee170d68802e (from https://pypi.org/simple/sklearn/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   ERROR: Command errored out with exit status 1:
#    command: 'd:\tweepfake_deepfake_text_detection\venv\scripts\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\ESDRAS~1\\AppData\\Local\\Temp\\pip-install-l0xnbmve\\sklearn_daafae634a9143158565ab698fac7cbb\\setup.py'"'"'; __file__='"'"'C:\\Users\\ESDRAS~1\\AppData\\Local\\Temp\\pip-install-l0xnbmve\\sklearn_daafae634a9143158565ab698fac7cbb\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\ESDRAS~1\AppData\Local\Temp\pip-pip-egg-info-6sywhg05'
#        cwd: C:\Users\ESDRAS~1\AppData\Local\Temp\pip-install-l0xnbmve\sklearn_daafae634a9143158565ab698fac7cbb\
#   Complete output (18 lines):
#   The 'sklearn' PyPI package is deprecated, use 'scikit-learn'
#   rather than 'sklearn' for pip commands.
#
#   Here is how to fix this error in the main use cases:
#   - use 'pip install scikit-learn' rather than 'pip install sklearn'
#   - replace 'sklearn' by 'scikit-learn' in your pip requirements files
#     (requirements.txt, setup.py, setup.cfg, Pipfile, etc ...)
#   - if the 'sklearn' package is used by one of your dependencies,
#     it would be great if you take some time to track which package uses
#     'sklearn' instead of 'scikit-learn' and report it to their issue tracker
#   - as a last resort, set the environment variable
#     SKLEARN_ALLOW_DEPRECATED_SKLEARN_PACKAGE_INSTALL=True to avoid this error
#
#   More information is available at
#   https://github.com/scikit-learn/sklearn-pypi-package
#
#   If the previous advice does not cover your use case, feel free to report it at
#   https://github.com/scikit-learn/sklearn-pypi-package/issues/new
#   ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/a4/0b/d1c703256cf293be77b7db44dbef62251fe02a97d0bef981f7120b0b0c0f/sklearn-0.0.post11.tar.gz#sha256=af035c4f0b970b7fc2d3856079aa1aa1032df3d7f65048a9d87114abf13c4629 (from https://pypi.org/simple/sklearn/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   ERROR: Command errored out with exit status 1:
#    command: 'd:\tweepfake_deepfake_text_detection\venv\scripts\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\ESDRAS~1\\AppData\\Local\\Temp\\pip-install-l0xnbmve\\sklearn_7ecc779e4140415eb55d62d5435bd662\\setup.py'"'"'; __file__='"'"'C:\\Users\\ESDRAS~1\\AppData\\Local\\Temp\\pip-install-l0xnbmve\\sklearn_7ecc779e4140415eb55d62d5435bd662\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\ESDRAS~1\AppData\Local\Temp\pip-pip-egg-info-jp5i7wh0'
#        cwd: C:\Users\ESDRAS~1\AppData\Local\Temp\pip-install-l0xnbmve\sklearn_7ecc779e4140415eb55d62d5435bd662\
#   Complete output (18 lines):
#   The 'sklearn' PyPI package is deprecated, use 'scikit-learn'
#   rather than 'sklearn' for pip commands.
#
#   Here is how to fix this error in the main use cases:
#   - use 'pip install scikit-learn' rather than 'pip install sklearn'
#   - replace 'sklearn' by 'scikit-learn' in your pip requirements files
#     (requirements.txt, setup.py, setup.cfg, Pipfile, etc ...)
#   - if the 'sklearn' package is used by one of your dependencies,
#     it would be great if you take some time to track which package uses
#     'sklearn' instead of 'scikit-learn' and report it to their issue tracker
#   - as a last resort, set the environment variable
#     SKLEARN_ALLOW_DEPRECATED_SKLEARN_PACKAGE_INSTALL=True to avoid this error
#
#   More information is available at
#   https://github.com/scikit-learn/sklearn-pypi-package
#
#   If the previous advice does not cover your use case, feel free to report it at
#   https://github.com/scikit-learn/sklearn-pypi-package/issues/new
#   ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/b9/0e/b2a4cfaa9e12b9ca4c71507bc26d2c99d75de172c0088c9835a98cf146ff/sklearn-0.0.post10.tar.gz#sha256=d4cd5a2e64b3caaf82cd5e33c46884dfeec5ebf991710d9faeb4fe81cadb3ba6 (from https://pypi.org/simple/sklearn/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   ERROR: Command errored out with exit status 1:
#    command: 'd:\tweepfake_deepfake_text_detection\venv\scripts\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\ESDRAS~1\\AppData\\Local\\Temp\\pip-install-l0xnbmve\\sklearn_43297041d5364602847ef0aae58db395\\setup.py'"'"'; __file__='"'"'C:\\Users\\ESDRAS~1\\AppData\\Local\\Temp\\pip-install-l0xnbmve\\sklearn_43297041d5364602847ef0aae58db395\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\ESDRAS~1\AppData\Local\Temp\pip-pip-egg-info-3cmmpij8'
#        cwd: C:\Users\ESDRAS~1\AppData\Local\Temp\pip-install-l0xnbmve\sklearn_43297041d5364602847ef0aae58db395\
#   Complete output (18 lines):
#   The 'sklearn' PyPI package is deprecated, use 'scikit-learn'
#   rather than 'sklearn' for pip commands.
#
#   Here is how to fix this error in the main use cases:
#   - use 'pip install scikit-learn' rather than 'pip install sklearn'
#   - replace 'sklearn' by 'scikit-learn' in your pip requirements files
#     (requirements.txt, setup.py, setup.cfg, Pipfile, etc ...)
#   - if the 'sklearn' package is used by one of your dependencies,
#     it would be great if you take some time to track which package uses
#     'sklearn' instead of 'scikit-learn' and report it to their issue tracker
#   - as a last resort, set the environment variable
#     SKLEARN_ALLOW_DEPRECATED_SKLEARN_PACKAGE_INSTALL=True to avoid this error
#
#   More information is available at
#   https://github.com/scikit-learn/sklearn-pypi-package
#
#   If the previous advice does not cover your use case, feel free to report it at
#   https://github.com/scikit-learn/sklearn-pypi-package/issues/new
#   ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/28/86/207a003339023247fef1bb5bc9f5093140d17294b2f6d15bfcd4885e469e/sklearn-0.0.post9.tar.gz#sha256=1ff5864cf30489ee48a014fe8f4320d7bb59592392a4ef52ae9d7a37942615ac (from https://pypi.org/simple/sklearn/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   ERROR: Command errored out with exit status 1:
#    command: 'd:\tweepfake_deepfake_text_detection\venv\scripts\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\ESDRAS~1\\AppData\\Local\\Temp\\pip-install-l0xnbmve\\sklearn_83867df77e1c4323837c3f19421aa263\\setup.py'"'"'; __file__='"'"'C:\\Users\\ESDRAS~1\\AppData\\Local\\Temp\\pip-install-l0xnbmve\\sklearn_83867df77e1c4323837c3f19421aa263\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\ESDRAS~1\AppData\Local\Temp\pip-pip-egg-info-q6k8ies7'
#        cwd: C:\Users\ESDRAS~1\AppData\Local\Temp\pip-install-l0xnbmve\sklearn_83867df77e1c4323837c3f19421aa263\
#   Complete output (18 lines):
#   The 'sklearn' PyPI package is deprecated, use 'scikit-learn'
#   rather than 'sklearn' for pip commands.
#
#   Here is how to fix this error in the main use cases:
#   - use 'pip install scikit-learn' rather than 'pip install sklearn'
#   - replace 'sklearn' by 'scikit-learn' in your pip requirements files
#     (requirements.txt, setup.py, setup.cfg, Pipfile, etc ...)
#   - if the 'sklearn' package is used by one of your dependencies,
#     it would be great if you take some time to track which package uses
#     'sklearn' instead of 'scikit-learn' and report it to their issue tracker
#   - as a last resort, set the environment variable
#     SKLEARN_ALLOW_DEPRECATED_SKLEARN_PACKAGE_INSTALL=True to avoid this error
#
#   More information is available at
#   https://github.com/scikit-learn/sklearn-pypi-package
#
#   If the previous advice does not cover your use case, feel free to report it at
#   https://github.com/scikit-learn/sklearn-pypi-package/issues/new
#   ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/70/ce/81aa643f3c43488c4a1e417e45f696a61e7ac82b57190fad3c310df2c07b/sklearn-0.0.post7.tar.gz#sha256=1c89020b364fdc3aa2839e0ae34e8f0b406669e4b5c2359dda3ac398f9c76874 (from https://pypi.org/simple/sklearn/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   ERROR: Command errored out with exit status 1:
#    command: 'd:\tweepfake_deepfake_text_detection\venv\scripts\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\ESDRAS~1\\AppData\\Local\\Temp\\pip-install-l0xnbmve\\sklearn_9bf766438de54758b6ca2271bf92ceae\\setup.py'"'"'; __file__='"'"'C:\\Users\\ESDRAS~1\\AppData\\Local\\Temp\\pip-install-l0xnbmve\\sklearn_9bf766438de54758b6ca2271bf92ceae\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\ESDRAS~1\AppData\Local\Temp\pip-pip-egg-info-7p13g5p_'
#        cwd: C:\Users\ESDRAS~1\AppData\Local\Temp\pip-install-l0xnbmve\sklearn_9bf766438de54758b6ca2271bf92ceae\
#   Complete output (18 lines):
#   The 'sklearn' PyPI package is deprecated, use 'scikit-learn'
#   rather than 'sklearn' for pip commands.
#
#   Here is how to fix this error in the main use cases:
#   - use 'pip install scikit-learn' rather than 'pip install sklearn'
#   - replace 'sklearn' by 'scikit-learn' in your pip requirements files
#     (requirements.txt, setup.py, setup.cfg, Pipfile, etc ...)
#   - if the 'sklearn' package is used by one of your dependencies,
#     it would be great if you take some time to track which package uses
#     'sklearn' instead of 'scikit-learn' and report it to their issue tracker
#   - as a last resort, set the environment variable
#     SKLEARN_ALLOW_DEPRECATED_SKLEARN_PACKAGE_INSTALL=True to avoid this error
#
#   More information is available at
#   https://github.com/scikit-learn/sklearn-pypi-package
#
#   If the previous advice does not cover your use case, feel free to report it at
#   https://github.com/scikit-learn/sklearn-pypi-package/issues/new
#   ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/7a/93/e0e1b1e98f39dfca7ec9795cb46f6e09e88a2fd5d4a28e4b3d1f618a2aec/sklearn-0.0.post5.tar.gz#sha256=7377c714a03a79bbe9196f435db931fd2a6fa8c68514da7ed3a251fd08c52e2c (from https://pypi.org/simple/sklearn/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   ERROR: Command errored out with exit status 1:
#    command: 'd:\tweepfake_deepfake_text_detection\venv\scripts\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\ESDRAS~1\\AppData\\Local\\Temp\\pip-install-l0xnbmve\\sklearn_cccba7926b1d404187f47fdff4ce0e91\\setup.py'"'"'; __file__='"'"'C:\\Users\\ESDRAS~1\\AppData\\Local\\Temp\\pip-install-l0xnbmve\\sklearn_cccba7926b1d404187f47fdff4ce0e91\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\ESDRAS~1\AppData\Local\Temp\pip-pip-egg-info-ra6zb04j'
#        cwd: C:\Users\ESDRAS~1\AppData\Local\Temp\pip-install-l0xnbmve\sklearn_cccba7926b1d404187f47fdff4ce0e91\
#   Complete output (7 lines):
#   Traceback (most recent call last):
#     File "<string>", line 1, in <module>
#     File "C:\Users\ESDRAS~1\AppData\Local\Temp\pip-install-l0xnbmve\sklearn_cccba7926b1d404187f47fdff4ce0e91\setup.py", line 10, in <module>
#       LONG_DESCRIPTION = f.read()
#     File "C:\Users\Esdras Samuel\AppData\Local\Programs\Python\Python36\lib\encodings\cp1252.py", line 23, in decode
#       return codecs.charmap_decode(input,self.errors,decoding_table)[0]
#   UnicodeDecodeError: 'charmap' codec can't decode byte 0x8f in position 7: character maps to <undefined>
#   ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/99/b2/165110013aa66fae6fc13918ad0e9de4801e5f1691d371bf8b63328037e6/sklearn-0.0.post4.tar.gz#sha256=0e81ec9c32d4bb418e7be8f1ec1027d174975502dc84cbc4f4564b4cba31e674 (from https://pypi.org/simple/sklearn/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   ERROR: Command errored out with exit status 1:
#    command: 'd:\tweepfake_deepfake_text_detection\venv\scripts\python.exe' -c 'import io, os, sys, setuptools, tokenize; sys.argv[0] = '"'"'C:\\Users\\ESDRAS~1\\AppData\\Local\\Temp\\pip-install-l0xnbmve\\sklearn_e058956a908f4143b51a204820675d22\\setup.py'"'"'; __file__='"'"'C:\\Users\\ESDRAS~1\\AppData\\Local\\Temp\\pip-install-l0xnbmve\\sklearn_e058956a908f4143b51a204820675d22\\setup.py'"'"';f = getattr(tokenize, '"'"'open'"'"', open)(__file__) if os.path.exists(__file__) else io.StringIO('"'"'from setuptools import setup; setup()'"'"');code = f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' egg_info --egg-base 'C:\Users\ESDRAS~1\AppData\Local\Temp\pip-pip-egg-info-hiwhezpm'
#        cwd: C:\Users\ESDRAS~1\AppData\Local\Temp\pip-install-l0xnbmve\sklearn_e058956a908f4143b51a204820675d22\
#   Complete output (18 lines):
#   The 'sklearn' PyPI package is deprecated, use 'scikit-learn'
#   rather than 'sklearn' for pip commands.
#
#   Here is how to fix this error in the main use cases:
#   - use 'pip install scikit-learn' rather than 'pip install sklearn'
#   - replace 'sklearn' by 'scikit-learn' in your pip requirements files
#     (requirements.txt, setup.py, setup.cfg, Pipfile, etc ...)
#   - if the 'sklearn' package is used by one of your dependencies,
#     it would be great if you take some time to track which package uses
#     'sklearn' instead of 'scikit-learn' and report it to their issue tracker
#   - as a last resort, set the environment variable
#     SKLEARN_ALLOW_DEPRECATED_SKLEARN_PACKAGE_INSTALL=True to avoid this error
#
#   More information is available at
#   https://github.com/scikit-learn/sklearn-pypi-package
#
#   If the previous advice does not cover your use case, feel free to report it at
#   https://github.com/scikit-learn/sklearn-pypi-package/issues/new
#   ----------------------------------------
# WARNING: Discarding https://files.pythonhosted.org/packages/db/1e/af4e9cded5093a92e60d4ae7149a02c7427661b2db66c8ea4d34b17864a2/sklearn-0.0.post1.tar.gz#sha256=76b9ed1623775168657b86b5fe966d45752e5c87f528de6240c38923b94147c5 (from https://pypi.org/simple/sklearn/). Command errored out with exit status 1: python setup.py egg_info Check the logs for full command output.
#   Downloading sklearn-0.0.post4.tar.gz (3.6 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'error'
#   Downloading sklearn-0.0.post1.tar.gz (3.6 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'error'
#   Downloading sklearn-0.0.tar.gz (1.1 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting scikit-learn
#   Downloading scikit_learn-0.24.2-cp36-cp36m-win_amd64.whl (6.8 MB)
# Collecting joblib>=0.11
#   Downloading joblib-1.1.1-py2.py3-none-any.whl (309 kB)
# Collecting threadpoolctl>=2.0.0
#   Downloading threadpoolctl-3.1.0-py3-none-any.whl (14 kB)
# Requirement already satisfied: scipy>=0.19.1 in d:\tweepfake_deepfake_text_detection\venv\lib\site-packages (from scikit-learn->sklearn) (1.4.1)
# Requirement already satisfied: numpy>=1.13.3 in d:\tweepfake_deepfake_text_detection\venv\lib\site-packages (from scikit-learn->sklearn) (1.18.5)
# Building wheels for collected packages: sklearn
#   Building wheel for sklearn (setup.py): started
#   Building wheel for sklearn (setup.py): finished with status 'done'
#   Created wheel for sklearn: filename=sklearn-0.0-py2.py3-none-any.whl size=1310 sha256=564761cfee1e19e5da9fc1c169a1258297bbca48bae340d959d3af3a641447c1
#   Stored in directory: c:\users\esdras samuel\appdata\local\pip\cache\wheels\23\9d\42\5ec745cbbb17517000a53cecc49d6a865450d1f5cb16dc8a9c
# Successfully built sklearn
# Installing collected packages: threadpoolctl, joblib, scikit-learn, sklearn
# Successfully installed joblib-1.1.1 scikit-learn-0.24.2 sklearn-0.0 threadpoolctl-3.1.0

# %%
from DataHandler import DataHandler

csvTrainDataset = "./data/splits/train.csv"
csvValDataset = "./data/splits/validation.csv"
csvTestDataset = "./data/splits/test.csv"

charDir = "/data/encoded/char"
dh = DataHandler()
dfTrain = dh.readCSVData(csvTrainDataset)
dfVal = dh.readCSVData(csvValDataset)
dfTest = dh.readCSVData(csvTestDataset)
# Out:
# ./data/splits/train.csv
# ./data/splits/validation.csv
# ./data/splits/test.csv

# %%
dfTrain
# Out:
#           screen_name                                               text  \
# 0          imranyebot                             YEA now that note GOOD
# 1              zawvrk  Listen to This Charming Man by The Smiths  htt...
# 2            zawarbot  wish i can i would be seeing other hoes on the...
# 3      ahadsheriffbot  The decade in the significantly easier schedul...
# 4       kevinhookebot  "Theim class=\"alignnone size-full wp-image-60...
# ...               ...                                                ...
# 20707  AINarendraModi  Met on the Abversion of our science for the co...
# 20708  AINarendraModi  Land for their during the opportunity to the p...
# 20709      DeepDrumpf  @TayandYou doesn't have a clue. You're right. ...
# 20710           jaden           Me And My Bestie https://t.co/vPq2iDkWZm
# 20711   kevinhookebot  "Thead has a generate existing the Sparching f...
#
#       account.type class_type
# 0              bot     others
# 1            human      human
# 2              bot     others
# 3              bot     others
# 4              bot        rnn
# ...            ...        ...
# 20707          bot        rnn
# 20708          bot        rnn
# 20709          bot        rnn
# 20710        human      human
# 20711          bot        rnn
#
# [20712 rows x 4 columns]

# %%
# Select interesting columns for this study.
dfTrainDataset = dfTrain[["screen_name", "text", "account.type"]]
dfValDataset = dfVal[["screen_name", "text", "account.type"]]
dfTestDataset = dfTest[["screen_name", "text", "account.type"]]

# %%
dfTrainDataset
# Out:
#           screen_name                                               text  \
# 0          imranyebot                             YEA now that note GOOD
# 1              zawvrk  Listen to This Charming Man by The Smiths  htt...
# 2            zawarbot  wish i can i would be seeing other hoes on the...
# 3      ahadsheriffbot  The decade in the significantly easier schedul...
# 4       kevinhookebot  "Theim class=\"alignnone size-full wp-image-60...
# ...               ...                                                ...
# 20707  AINarendraModi  Met on the Abversion of our science for the co...
# 20708  AINarendraModi  Land for their during the opportunity to the p...
# 20709      DeepDrumpf  @TayandYou doesn't have a clue. You're right. ...
# 20710           jaden           Me And My Bestie https://t.co/vPq2iDkWZm
# 20711   kevinhookebot  "Thead has a generate existing the Sparching f...
#
#       account.type
# 0              bot
# 1            human
# 2              bot
# 3              bot
# 4              bot
# ...            ...
# 20707          bot
# 20708          bot
# 20709          bot
# 20710        human
# 20711          bot
#
# [20712 rows x 3 columns]

# %%
import os
import tensorflow as tf
from numpy import savetxt
from numpy import loadtxt

import sys
sys.path.append("D:\tweepfake_deepfake_text_detection")

from KerasModels import generateExpData

tokenizer = None
train_features, tokenizer = generateExpData(dfTrainDataset, tokenizer = tokenizer)
val_features, tokenizer = generateExpData(dfValDataset, tokenizer = tokenizer)
test_features, tokenizer = generateExpData(dfTestDataset, tokenizer = tokenizer)

# %%
X_train_all = dfTrainDataset
X_val_all = dfValDataset
X_test_all = dfTestDataset
dictLabels = {"human":0, "bot":1}
dictLabelsReverse = {0:"human", 1: "bot"}
y_train = dfTrainDataset["account.type"].apply(lambda x: dictLabels[x])
y_val = dfValDataset["account.type"].apply(lambda x: dictLabels[x])
y_test = dfTestDataset["account.type"].apply(lambda x: dictLabels[x])

# %%
import numpy as np #as Failed to find data adapter that can handle input: <class 'numpy.ndarray'>, (<class 'list'> containing values of types {"<class 'int'>"})

train_labels = np.array(train_labels)
val_labels = np.array(val_labels)
test_labels = np.array(test_labels)

# %%
from KerasModels import buildCharCNNModel

# Build char CNN network.
vocab_size = len(tokenizer.word_index)
model = buildCharCNNModel(vocab_size, embSize=32, inputSize=320)
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            [(None, 320)]        0
# __________________________________________________________________________________________________
# embedding_2 (Embedding)         (None, 320, 32)      3456        input_3[0][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, 318, 128)     12416       embedding_2[0][0]
# __________________________________________________________________________________________________
# conv1d_7 (Conv1D)               (None, 317, 128)     16512       embedding_2[0][0]
# __________________________________________________________________________________________________
# conv1d_8 (Conv1D)               (None, 316, 128)     20608       embedding_2[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_6 (GlobalM (None, 128)          0           conv1d_6[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_7 (GlobalM (None, 128)          0           conv1d_7[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_8 (GlobalM (None, 128)          0           conv1d_8[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 384)          0           global_max_pooling1d_6[0][0]
#                                                                  global_max_pooling1d_7[0][0]
#                                                                  global_max_pooling1d_8[0][0]
# __________________________________________________________________________________________________
# dropout_2 (Dropout)             (None, 384)          0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# dense_2 (Dense)                 (None, 1)            385         dropout_2[0][0]
# ==================================================================================================
# Total params: 53,377
# Trainable params: 53,377
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
# Train CNN model.
model.fit(train_features, train_labels, batch_size=256, epochs=25, validation_data=(val_features, val_labels))
# Out:
# Epoch 1/25
# 81/81 [==============================] - 43s 535ms/step - loss: 0.5602 - accuracy: 0.7181 - val_loss: 0.4765 - val_accuracy: 0.7706
# Epoch 2/25
# 81/81 [==============================] - 37s 460ms/step - loss: 0.4183 - accuracy: 0.8058 - val_loss: 0.4081 - val_accuracy: 0.7993
# Epoch 3/25
# 81/81 [==============================] - 40s 493ms/step - loss: 0.3779 - accuracy: 0.8235 - val_loss: 0.3857 - val_accuracy: 0.8180
# Epoch 4/25
# 81/81 [==============================] - 43s 532ms/step - loss: 0.3635 - accuracy: 0.8297 - val_loss: 0.3746 - val_accuracy: 0.8288
# Epoch 5/25
# 81/81 [==============================] - 42s 516ms/step - loss: 0.3527 - accuracy: 0.8357 - val_loss: 0.3656 - val_accuracy: 0.8323
# Epoch 6/25
# 81/81 [==============================] - 45s 552ms/step - loss: 0.3449 - accuracy: 0.8418 - val_loss: 0.3604 - val_accuracy: 0.8371
# Epoch 7/25
# 81/81 [==============================] - 46s 572ms/step - loss: 0.3360 - accuracy: 0.8450 - val_loss: 0.3559 - val_accuracy: 0.8393
# Epoch 8/25
# 81/81 [==============================] - 42s 517ms/step - loss: 0.3266 - accuracy: 0.8485 - val_loss: 0.3495 - val_accuracy: 0.8445
# Epoch 9/25
# 81/81 [==============================] - 42s 518ms/step - loss: 0.3199 - accuracy: 0.8545 - val_loss: 0.3485 - val_accuracy: 0.8367
# Epoch 10/25
# 81/81 [==============================] - 40s 497ms/step - loss: 0.3123 - accuracy: 0.8567 - val_loss: 0.3481 - val_accuracy: 0.8427
# Epoch 11/25
# 81/81 [==============================] - 43s 527ms/step - loss: 0.3065 - accuracy: 0.8604 - val_loss: 0.3398 - val_accuracy: 0.8454
# Epoch 12/25
# 81/81 [==============================] - 41s 504ms/step - loss: 0.2996 - accuracy: 0.8655 - val_loss: 0.3356 - val_accuracy: 0.8380
# Epoch 13/25
# 81/81 [==============================] - 41s 508ms/step - loss: 0.2928 - accuracy: 0.8682 - val_loss: 0.3377 - val_accuracy: 0.8419
# Epoch 14/25
# 81/81 [==============================] - 43s 534ms/step - loss: 0.2850 - accuracy: 0.8727 - val_loss: 0.3371 - val_accuracy: 0.8354
# Epoch 15/25
# 81/81 [==============================] - 41s 507ms/step - loss: 0.2780 - accuracy: 0.8754 - val_loss: 0.3298 - val_accuracy: 0.8388
# Epoch 16/25
# 81/81 [==============================] - 41s 505ms/step - loss: 0.2708 - accuracy: 0.8804 - val_loss: 0.3330 - val_accuracy: 0.8493
# Epoch 17/25
# 81/81 [==============================] - 43s 529ms/step - loss: 0.2667 - accuracy: 0.8827 - val_loss: 0.3223 - val_accuracy: 0.8449
# Epoch 18/25
# 81/81 [==============================] - 40s 499ms/step - loss: 0.2574 - accuracy: 0.8878 - val_loss: 0.3226 - val_accuracy: 0.8471
# Epoch 19/25
# 81/81 [==============================] - 40s 499ms/step - loss: 0.2492 - accuracy: 0.8907 - val_loss: 0.3267 - val_accuracy: 0.8510
# Epoch 20/25
# 81/81 [==============================] - 43s 537ms/step - loss: 0.2434 - accuracy: 0.8971 - val_loss: 0.3204 - val_accuracy: 0.8454
# Epoch 21/25
# 81/81 [==============================] - 41s 511ms/step - loss: 0.2362 - accuracy: 0.8982 - val_loss: 0.3215 - val_accuracy: 0.8397
# Epoch 22/25
# 81/81 [==============================] - 40s 500ms/step - loss: 0.2329 - accuracy: 0.8990 - val_loss: 0.3251 - val_accuracy: 0.8410
# Epoch 23/25
# 81/81 [==============================] - 43s 528ms/step - loss: 0.2237 - accuracy: 0.9041 - val_loss: 0.3230 - val_accuracy: 0.8419
# Epoch 24/25
# 81/81 [==============================] - 40s 492ms/step - loss: 0.2167 - accuracy: 0.9099 - val_loss: 0.3248 - val_accuracy: 0.8380
# Epoch 25/25
# 81/81 [==============================] - 40s 492ms/step - loss: 0.2085 - accuracy: 0.9154 - val_loss: 0.3184 - val_accuracy: 0.8449

# %%
y_pred_char_cnn_prob = model.predict(test_features)
y_pred_char_cnn = (y_pred_char_cnn_prob > 0.5)
def toBoolValue(v):
  if v == True:
    return 1
  else:
    return 0
y_pred_char_cnn = [toBoolValue(t) for t in y_pred_char_cnn]

# %%
import pandas as pd

predictionLabels = [dictLabelsReverse[t] for t in y_pred_char_cnn]
dfResults = pd.DataFrame(predictionLabels, columns=["prediction"])
dfResults["gold"] = dfTestDataset[["account.type"]]
file_name = resultsDir+"/char_cnn.csv"
dfResults.to_csv(file_name, sep='\t', encoding='utf-8')

# %%
from sklearn.metrics import classification_report

print(classification_report(test_labels, y_pred_char_cnn, digits=3))
# Out:
#               precision    recall  f1-score   support
#
#            0      0.881     0.798     0.837      1278
#            1      0.816     0.892     0.852      1280
#
#     accuracy                          0.845      2558
#    macro avg      0.848     0.845     0.845      2558
# weighted avg      0.848     0.845     0.845      2558

# %%
X_test_all["label_char_cnn"] = [dictLabelsReverse[t] for t in y_pred_char_cnn]

# %%
def plotErrorRatio(X_test_all, prediction_column, min_sample_num=30):
  X_verify = X_test_all[["screen_name", "text", "account.type", prediction_column]]
  X_count_accounts = X_test_all[["screen_name", "account.type"]].groupby("screen_name").count()
  X_verify = X_verify[X_verify["account.type"] != X_verify[prediction_column]]
  X_verify = X_verify.groupby("screen_name").count()["text"].to_frame()
  X_verify["total"] = X_count_accounts["account.type"]
  X_verify.columns = ["errors", "num_samples"]
  X_verify["error_ratio"] = X_verify["errors"] / X_verify["num_samples"]
  X_verify[X_verify["num_samples"] >= min_sample_num]["error_ratio"].plot.bar(figsize=(15,5))
  return X_verify

# %%
#!pip install matplotlib==3.3.1
plotErrorRatio(X_test_all, "label_char_cnn", min_sample_num=30)
# Out:
#                  errors  num_samples  error_ratio
# screen_name
# AINarendraModi        4          125     0.032000
# DeepDrumpf            2           29     0.068966
# GenePark              2           22     0.090909
# GenePark_GPT2         5           22     0.227273
# Gpt2Wint              2            2     1.000000
# JustinTrudeau         3           51     0.058824
# Musk_from_Mars        1            2     0.500000
# Thorin                3           10     0.300000
# UtilityLimb           3            4     0.750000
# VBoterin              1           13     0.076923
# VitalikButerin        2           13     0.153846
# ahadsheriff          22           95     0.231579
# ahadsheriffbot        9           95     0.094737
# awhalefact            4           35     0.114286
# botustrump            5           35     0.142857
# calebgamman           7           13     0.538462
# calebgamman2          2           13     0.153846
# deep_thorin           1           10     0.100000
# dril                 71          180     0.394444
# dril_gpt2            57          179     0.318436
# elonmusk              2            6     0.333333
# gpt2_trump           18           55     0.327273
# imranye              29          129     0.224806
# imranyebot            8          129     0.062016
# jaden                16           51     0.313725
# kevinhooke            8          241     0.033195
# narendramodi          8          124     0.064516
# ninjasexparty        14           23     0.608696
# nsp_gpt2              4           23     0.173913
# realDonaldTrump      14          129     0.108527
# sarcastic_trump       2            5     0.400000
# theJadenTrudeau       2          103     0.019417
# utilitylimbgpt2       2            4     0.500000
# zawarbot             13          152     0.085526
# zawvrk               50          152     0.328947

# %%
from KerasModels import buildCharGRUModel


# Build char GRU network.
vocab_size = len(tokenizer.word_index)
model = buildCharGRUModel(vocab_size, embSize=32, inputSize=320)
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         (None, 320)               0
# _________________________________________________________________
# embedding_2 (Embedding)      (None, 320, 32)           3456
# _________________________________________________________________
# bidirectional_1 (Bidirection (None, 1024)              1674240
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 1025
# =================================================================
# Total params: 1,678,721
# Trainable params: 1,678,721
# Non-trainable params: 0
# _________________________________________________________________
# None

# %%
# Train LSTM model.
model.fit(train_features, train_labels, batch_size=256, epochs=25, validation_data=(val_features, val_labels))
# Out:
# Train on 20712 samples, validate on 2302 samples
# Epoch 1/25
# 20712/20712 [==============================] - 66s 3ms/step - loss: 0.6496 - accuracy: 0.6018 - val_loss: 0.6028 - val_accuracy: 0.6216
# Epoch 2/25
# 20712/20712 [==============================] - 64s 3ms/step - loss: 0.5902 - accuracy: 0.6381 - val_loss: 0.5862 - val_accuracy: 0.6520
# Epoch 3/25
# 20712/20712 [==============================] - 64s 3ms/step - loss: 0.5848 - accuracy: 0.6623 - val_loss: 0.5872 - val_accuracy: 0.6512
# Epoch 4/25
# 20712/20712 [==============================] - 64s 3ms/step - loss: 0.5824 - accuracy: 0.6496 - val_loss: 0.5821 - val_accuracy: 0.6490
# Epoch 5/25
# 20712/20712 [==============================] - 64s 3ms/step - loss: 0.5784 - accuracy: 0.6548 - val_loss: 0.5767 - val_accuracy: 0.6616
# Epoch 6/25
# 20712/20712 [==============================] - 64s 3ms/step - loss: 0.5131 - accuracy: 0.7255 - val_loss: 0.4391 - val_accuracy: 0.7854
# Epoch 7/25
# 20712/20712 [==============================] - 65s 3ms/step - loss: 0.4244 - accuracy: 0.8049 - val_loss: 0.4392 - val_accuracy: 0.7897
# Epoch 8/25
# 20712/20712 [==============================] - 65s 3ms/step - loss: 0.4221 - accuracy: 0.8060 - val_loss: 0.4368 - val_accuracy: 0.7889
# Epoch 9/25
# 20712/20712 [==============================] - 65s 3ms/step - loss: 0.4190 - accuracy: 0.8063 - val_loss: 0.4369 - val_accuracy: 0.7889
# Epoch 10/25
# 20712/20712 [==============================] - 65s 3ms/step - loss: 0.4162 - accuracy: 0.8074 - val_loss: 0.4316 - val_accuracy: 0.7919
# Epoch 11/25
# 20712/20712 [==============================] - 65s 3ms/step - loss: 0.4154 - accuracy: 0.8075 - val_loss: 0.4347 - val_accuracy: 0.7911
# Epoch 12/25
# 20712/20712 [==============================] - 64s 3ms/step - loss: 0.4126 - accuracy: 0.8093 - val_loss: 0.4335 - val_accuracy: 0.7906
# Epoch 13/25
# 20712/20712 [==============================] - 65s 3ms/step - loss: 0.4118 - accuracy: 0.8100 - val_loss: 0.4294 - val_accuracy: 0.7950
# Epoch 14/25
# 20712/20712 [==============================] - 64s 3ms/step - loss: 0.4163 - accuracy: 0.8074 - val_loss: 0.4344 - val_accuracy: 0.7889
# Epoch 15/25
# 20712/20712 [==============================] - 64s 3ms/step - loss: 0.4109 - accuracy: 0.8091 - val_loss: 0.4295 - val_accuracy: 0.7906
# Epoch 16/25
# 20712/20712 [==============================] - 65s 3ms/step - loss: 0.4087 - accuracy: 0.8098 - val_loss: 0.4312 - val_accuracy: 0.7919
# Epoch 17/25
# 20712/20712 [==============================] - 65s 3ms/step - loss: 0.4060 - accuracy: 0.8100 - val_loss: 0.4285 - val_accuracy: 0.7911
# Epoch 18/25
# 20712/20712 [==============================] - 65s 3ms/step - loss: 0.4036 - accuracy: 0.8104 - val_loss: 0.4290 - val_accuracy: 0.7919
# Epoch 19/25
# 20712/20712 [==============================] - 65s 3ms/step - loss: 0.4018 - accuracy: 0.8110 - val_loss: 0.4311 - val_accuracy: 0.7906
# Epoch 20/25
# 20712/20712 [==============================] - 65s 3ms/step - loss: 0.3990 - accuracy: 0.8125 - val_loss: 0.4256 - val_accuracy: 0.7941
# Epoch 21/25
# 20712/20712 [==============================] - 65s 3ms/step - loss: 0.3901 - accuracy: 0.8176 - val_loss: 0.4057 - val_accuracy: 0.8189
# Epoch 22/25
# 20712/20712 [==============================] - 66s 3ms/step - loss: 0.3804 - accuracy: 0.8273 - val_loss: 0.4072 - val_accuracy: 0.8063
# Epoch 23/25
# 20712/20712 [==============================] - 65s 3ms/step - loss: 0.3685 - accuracy: 0.8384 - val_loss: 0.3936 - val_accuracy: 0.8162
# Epoch 24/25
# 20712/20712 [==============================] - 65s 3ms/step - loss: 0.3580 - accuracy: 0.8439 - val_loss: 0.3903 - val_accuracy: 0.8180
# Epoch 25/25
# 20712/20712 [==============================] - 65s 3ms/step - loss: 0.3545 - accuracy: 0.8437 - val_loss: 0.3859 - val_accuracy: 0.8175

# %%
y_pred_char_lstm_prob = model.predict(test_features)
y_pred_char_lstm = (y_pred_char_lstm_prob > 0.5)
def toBoolValue(v):
  if v == True:
    return 1
  else:
    return 0
y_pred_char_lstm = [toBoolValue(t) for t in y_pred_char_lstm]

# %%
import pandas as pd

predictionLabels = [dictLabelsReverse[t] for t in y_pred_char_lstm]
dfResults = pd.DataFrame(predictionLabels, columns=["prediction"])
dfResults["gold"] = dfTestDataset[["account.type"]]
file_name = resultsDir+"/char_gru.csv"
dfResults.to_csv(file_name, sep='\t', encoding='utf-8')

# %%
from sklearn.metrics import classification_report

print(classification_report(test_labels, y_pred_char_lstm, digits=3))
# Out:
#               precision    recall  f1-score   support
#
#            0      0.899     0.743     0.814      1278
#            1      0.781     0.916     0.844      1280
#
#     accuracy                          0.830      2558
#    macro avg      0.840     0.830     0.829      2558
# weighted avg      0.840     0.830     0.829      2558

# %%
X_test_all["label_char_lstm"] = [dictLabelsReverse[t] for t in y_pred_char_lstm]
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
plotErrorRatio(X_test_all, "label_char_lstm", min_sample_num=30)
# Out:
#                  errors  num_samples  error_ratio
# screen_name
# AINarendraModi        9          125     0.072000
# DeepDrumpf            4           29     0.137931
# GenePark              1           22     0.045455
# GenePark_GPT2         3           22     0.136364
# Gpt2Wint              1            2     0.500000
# JustinTrudeau         2           51     0.039216
# Musk_from_Mars        1            2     0.500000
# Thorin                1           10     0.100000
# UtilityLimb           4            4     1.000000
# VBoterin              2           13     0.153846
# ahadsheriff          27           95     0.284211
# ahadsheriffbot        9           95     0.094737
# awhalefact            3           35     0.085714
# botustrump            2           35     0.057143
# calebgamman           7           13     0.538462
# dril                111          180     0.616667
# dril_gpt2            30          179     0.167598
# elonmusk              1            6     0.166667
# gpt2_trump           32           55     0.581818
# imranye              31          129     0.240310
# imranyebot            6          129     0.046512
# jaden                23           51     0.450980
# kevinhooke           12          241     0.049793
# narendramodi          8          124     0.064516
# ninjasexparty        14           23     0.608696
# realDonaldTrump      27          129     0.209302
# theJadenTrudeau       3          103     0.029126
# zawarbot              5          152     0.032895
# zawvrk               56          152     0.368421

# %%
# Build char CNN+GRU network.
from KerasModels import buildCharCNNAndGRUModel
vocab_size = len(tokenizer.word_index)
model = buildCharCNNAndGRUModel(vocab_size, embSize=32, inputSize=320)
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_3 (InputLayer)            (None, 320)          0
# __________________________________________________________________________________________________
# embedding_3 (Embedding)         (None, 320, 32)      3456        input_3[0][0]
# __________________________________________________________________________________________________
# conv1d_4 (Conv1D)               (None, 318, 128)     12416       embedding_3[0][0]
# __________________________________________________________________________________________________
# conv1d_5 (Conv1D)               (None, 317, 128)     16512       embedding_3[0][0]
# __________________________________________________________________________________________________
# conv1d_6 (Conv1D)               (None, 316, 128)     20608       embedding_3[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_4 (GlobalM (None, 128)          0           conv1d_4[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_5 (GlobalM (None, 128)          0           conv1d_5[0][0]
# __________________________________________________________________________________________________
# global_max_pooling1d_6 (GlobalM (None, 128)          0           conv1d_6[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, 384)          0           global_max_pooling1d_4[0][0]
#                                                                  global_max_pooling1d_5[0][0]
#                                                                  global_max_pooling1d_6[0][0]
# __________________________________________________________________________________________________
# bidirectional_2 (Bidirectional) (None, 1024)         1674240     embedding_3[0][0]
# __________________________________________________________________________________________________
# dropout_3 (Dropout)             (None, 384)          0           concatenate_2[0][0]
# __________________________________________________________________________________________________
# dropout_4 (Dropout)             (None, 1024)         0           bidirectional_2[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, 1408)         0           dropout_3[0][0]
#                                                                  dropout_4[0][0]
# __________________________________________________________________________________________________
# dense_3 (Dense)                 (None, 1)            1409        concatenate_3[0][0]
# ==================================================================================================
# Total params: 1,728,641
# Trainable params: 1,728,641
# Non-trainable params: 0
# __________________________________________________________________________________________________
# None

# %%
# Train LSTM model.
model.fit(train_features, train_labels, batch_size=256, epochs=25, validation_data=(val_features, val_labels))
# Out:
# Train on 20712 samples, validate on 2302 samples
# Epoch 1/25
# 20712/20712 [==============================] - 68s 3ms/step - loss: 0.6216 - accuracy: 0.7150 - val_loss: 0.4711 - val_accuracy: 0.7767
# Epoch 2/25
# 20712/20712 [==============================] - 66s 3ms/step - loss: 0.4180 - accuracy: 0.8057 - val_loss: 0.4179 - val_accuracy: 0.7971
# Epoch 3/25
# 20712/20712 [==============================] - 67s 3ms/step - loss: 0.3848 - accuracy: 0.8197 - val_loss: 0.3949 - val_accuracy: 0.8084
# Epoch 4/25
# 20712/20712 [==============================] - 66s 3ms/step - loss: 0.3666 - accuracy: 0.8304 - val_loss: 0.3809 - val_accuracy: 0.8275
# Epoch 5/25
# 20712/20712 [==============================] - 66s 3ms/step - loss: 0.3559 - accuracy: 0.8357 - val_loss: 0.3699 - val_accuracy: 0.8328
# Epoch 6/25
# 20712/20712 [==============================] - 65s 3ms/step - loss: 0.3459 - accuracy: 0.8418 - val_loss: 0.3670 - val_accuracy: 0.8293
# Epoch 7/25
# 20712/20712 [==============================] - 66s 3ms/step - loss: 0.3396 - accuracy: 0.8439 - val_loss: 0.3598 - val_accuracy: 0.8375
# Epoch 8/25
# 20712/20712 [==============================] - 65s 3ms/step - loss: 0.3302 - accuracy: 0.8508 - val_loss: 0.3545 - val_accuracy: 0.8406
# Epoch 9/25
# 20712/20712 [==============================] - 66s 3ms/step - loss: 0.3237 - accuracy: 0.8525 - val_loss: 0.3478 - val_accuracy: 0.8397
# Epoch 10/25
# 20712/20712 [==============================] - 66s 3ms/step - loss: 0.3186 - accuracy: 0.8556 - val_loss: 0.3437 - val_accuracy: 0.8467
# Epoch 11/25
# 20712/20712 [==============================] - 65s 3ms/step - loss: 0.3122 - accuracy: 0.8561 - val_loss: 0.3419 - val_accuracy: 0.8471
# Epoch 12/25
# 20712/20712 [==============================] - 65s 3ms/step - loss: 0.3055 - accuracy: 0.8621 - val_loss: 0.3402 - val_accuracy: 0.8506
# Epoch 13/25
# 20712/20712 [==============================] - 66s 3ms/step - loss: 0.3008 - accuracy: 0.8659 - val_loss: 0.3361 - val_accuracy: 0.8440
# Epoch 14/25
# 20712/20712 [==============================] - 66s 3ms/step - loss: 0.2936 - accuracy: 0.8695 - val_loss: 0.3328 - val_accuracy: 0.8493
# Epoch 15/25
# 20712/20712 [==============================] - 67s 3ms/step - loss: 0.2887 - accuracy: 0.8721 - val_loss: 0.3375 - val_accuracy: 0.8510
# Epoch 16/25
# 20712/20712 [==============================] - 67s 3ms/step - loss: 0.2829 - accuracy: 0.8722 - val_loss: 0.3305 - val_accuracy: 0.8514
# Epoch 17/25
# 20712/20712 [==============================] - 67s 3ms/step - loss: 0.2772 - accuracy: 0.8755 - val_loss: 0.3409 - val_accuracy: 0.8536
# Epoch 18/25
# 20712/20712 [==============================] - 67s 3ms/step - loss: 0.2741 - accuracy: 0.8772 - val_loss: 0.3295 - val_accuracy: 0.8493
# Epoch 19/25
# 20712/20712 [==============================] - 68s 3ms/step - loss: 0.2667 - accuracy: 0.8834 - val_loss: 0.3292 - val_accuracy: 0.8506
# Epoch 20/25
# 20712/20712 [==============================] - 67s 3ms/step - loss: 0.2602 - accuracy: 0.8864 - val_loss: 0.3256 - val_accuracy: 0.8514
# Epoch 21/25
# 20712/20712 [==============================] - 67s 3ms/step - loss: 0.2526 - accuracy: 0.8878 - val_loss: 0.3329 - val_accuracy: 0.8549
# Epoch 22/25
# 20712/20712 [==============================] - 67s 3ms/step - loss: 0.2477 - accuracy: 0.8927 - val_loss: 0.3258 - val_accuracy: 0.8497
# Epoch 23/25
# 20712/20712 [==============================] - 67s 3ms/step - loss: 0.2404 - accuracy: 0.8973 - val_loss: 0.3233 - val_accuracy: 0.8545
# Epoch 24/25
# 20712/20712 [==============================] - 66s 3ms/step - loss: 0.2320 - accuracy: 0.9010 - val_loss: 0.3330 - val_accuracy: 0.8427
# Epoch 25/25
# 20712/20712 [==============================] - 67s 3ms/step - loss: 0.2310 - accuracy: 0.9001 - val_loss: 0.3306 - val_accuracy: 0.8454

# %%
y_pred_char_cnngru_prob = model.predict(test_features)
y_pred_char_cnngru_prob = (y_pred_char_cnngru_prob > 0.5)
def toBoolValue(v):
  if v == True:
    return 1
  else:
    return 0
y_pred_char_cnngru_prob = [toBoolValue(t) for t in y_pred_char_cnngru_prob]

# %%
import pandas as pd

predictionLabels = [dictLabelsReverse[t] for t in y_pred_char_cnngru_prob]
dfResults = pd.DataFrame(predictionLabels, columns=["prediction"])
dfResults["gold"] = dfTestDataset[["account.type"]]
file_name = resultsDir+"/char_cnngru.csv"
dfResults.to_csv(file_name, sep='\t', encoding='utf-8')

# %%
from sklearn.metrics import classification_report

print(classification_report(test_labels, y_pred_char_cnngru_prob, digits=3))
# Out:
#               precision    recall  f1-score   support
#
#            0      0.848     0.820     0.834      1278
#            1      0.826     0.853     0.839      1280
#
#     accuracy                          0.837      2558
#    macro avg      0.837     0.837     0.837      2558
# weighted avg      0.837     0.837     0.837      2558

# %%
X_test_all["label_char_cnngru"] = [dictLabelsReverse[t] for t in y_pred_char_cnngru_prob]
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
plotErrorRatio(X_test_all, "label_char_cnngru", min_sample_num=30)
# Out:
#                  errors  num_samples  error_ratio
# screen_name
# AINarendraModi       10          125     0.080000
# DeepDrumpf            2           29     0.068966
# GenePark              1           22     0.045455
# GenePark_GPT2         6           22     0.272727
# Gpt2Wint              2            2     1.000000
# JustinTrudeau         2           51     0.039216
# Musk_from_Mars        1            2     0.500000
# Thorin                1           10     0.100000
# UtilityLimb           3            4     0.750000
# VBoterin              4           13     0.307692
# ahadsheriff          21           95     0.221053
# ahadsheriffbot       10           95     0.105263
# awhalefact            3           35     0.085714
# botustrump            5           35     0.142857
# calebgamman           6           13     0.461538
# deep_thorin           2           10     0.200000
# dril                 58          180     0.322222
# dril_gpt2            79          179     0.441341
# elonmusk              2            6     0.333333
# gpt2_trump           19           55     0.345455
# imranye              30          129     0.232558
# imranyebot           19          129     0.147287
# jaden                19           51     0.372549
# kevinhooke            8          241     0.033195
# narendramodi          9          124     0.072581
# ninjasexparty        13           23     0.565217
# nsp_gpt2              5           23     0.217391
# realDonaldTrump       9          129     0.069767
# sarcastic_trump       1            5     0.200000
# theJadenTrudeau       5          103     0.048544
# utilitylimbgpt2       2            4     0.500000
# whalefakes            1           35     0.028571
# zawarbot             15          152     0.098684
# zawvrk               45          152     0.296053
